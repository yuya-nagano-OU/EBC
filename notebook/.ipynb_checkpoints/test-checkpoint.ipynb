# %%
using Healpix
using LinearAlgebra
using StaticArrays
using Base.Threads
using WignerD
using NPZ
using Plots
using PyPlot
using PyCall
using BenchmarkTools
hp = pyimport("healpy")
include("../src/EBC.jl")

# %%
nside = 16
cp = gen_ConvolutionParams_pc(nside = nside);
cp
# Out:
# ConvolutionParams_pc{Int64, Matrix{ComplexF64}, Vector{Int64}, Matrix{ComplexF64}}(16, 47, ComplexF64[1.0 + 1.0im 1.0 + 1.0im; 1.0 + 1.0im 1.0 + 1.0im], ComplexF64[1.0 + 1.0im 1.0 + 1.0im; 1.0 + 1.0im 1.0 + 1.0im], 2, [0, 47], ComplexF64[0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im])

# %%
lmax = nside*3-1
res = Resolution(nside)
# Out:
# Healpix resolution(NSIDE = 16)

# %%
# input beam
size = alm_idx(lmax,lmax,lmax)
blm_ = zeros(ComplexF64, 3, size)
blm = hp.blm_gauss(deg2rad(0.5), lmax = lmax, pol = true)
blm_[1,1:length(blm[1,:])] = blm[1,:]
blm_[2,1:length(blm[1,:])] = -blm[2,:]*sqrt(2)
blm_[3,1:length(blm[1,:])] = -blm[3,:]*sqrt(2);
@time blm_full = get_reorder_blm_optimized(blm_, lmax, 10);
# Out:
#   0.000371 seconds (3.00 k allocations: 142.156 KiB)

# %%
alm = npzread("./inputs/alm=CMB=r0=nside$nside.npy")
@time alm_full = get_reorder_alm_optimized(alm, lmax);
# Out:
#   0.186473 seconds (321.89 k allocations: 16.134 MiB, 99.63% compilation time)

# %%
data_path = "/data/n/n339/wigner_file/"
# Out:
# "/data/n/n339/wigner_file/"

# %%
@time initial_wignerd = [zeros(ComplexF64,2*i+1,2*i+1) for i in 0:cp.lmax]
@time eff_wignerD = [zeros(ComplexF64,2*i+1,2*i+1) for i in 0:cp.lmax];
#@time eff_wignerD  .= get_pc_total_effective_wignerD(cp, calc_phi[1], wd_onz[1,:], initial_wignerd, eff_wignerD);
# Out:
#   0.040837 seconds (41.27 k allocations: 4.404 MiB, 99.19% compilation time)
#   0.040031 seconds (41.27 k allocations: 4.404 MiB, 99.24% compilation time)

# %%
npix = nside2npix(nside)
utv = unique_theta_val(cp);

# %%
initial_wignerd_onz = zeros(ComplexF64, 3, 2*cp.lmax+1)
conv_binned_map = zeros(3,npix)
result_d = zeros(ComplexF64,3)
@time for i in 1:length(utv)
    @show i
    start_pix, stop_pix = unique_theta_num(i, cp)
    initialwignerds_array(cp, utv[i], data_path, initial_wignerd);
    for pix_num in start_pix:stop_pix
        center_th, center_phi = pix2angRing(res,pix_num)
        calc_psi = rand(100)*2pi
        effective_wignerD_onz(cp, calc_psi[:], initial_wignerd_onz)
        get_pc_total_effective_wignerD(cp, center_phi, initial_wignerd_onz[j,:], initial_wignerd, eff_wignerD);
        result_d[1:3] = eff_convolver_optimized(alm_full, blm_full, eff_wignerD, 10)
        conv = binned_mapmaker(calc_psi, result_d)
        conv_binned_map[:,pix_num] .= conv
    end
end
# Out:
# i = 1
# i = 2
# i = 3
# i = 4
# i = 5
# i = 6
# i = 7
# i = 8
# i = 9
# i = 10
# i = 11
# i = 12
# i = 13
# i = 14
# i = 15
# i = 16
# i = 17
# i = 18
# i = 19
# i = 20
# i = 21
# i = 22
# i = 23
# i = 24
# i = 25
# i = 26
# i = 27
# i = 28
# i = 29
# i = 30
# i = 31
# i = 32
# i = 33
# i = 34
# i = 35
# i = 36
# i = 37
# i = 38
# i = 39
# i = 40
# i = 41
# i = 42
# i = 43
# i = 44
# i = 45
# i = 46
# i = 47
# i = 48
# i = 49
# i = 50
# i = 51
# i = 52
# i = 53
# i = 54
# i = 55
# i = 56
# i = 57
# i = 58
# i = 59
# i = 60
# i = 61
# i = 62
# i = 63
#  31.123575 seconds (136.28 M allocations: 95.029 GiB, 17.82% gc time)

# %%
alm_smooth = hp.smoothalm([alm[1,:],alm[2,:],alm[3,:]],fwhm = deg2rad(0.5))
in_map = hp.alm2map([alm_smooth[1],alm_smooth[2],alm_smooth[3]], nside = nside)
# Out:
# 3×3072 Matrix{Float64}:
#  -37.2203    47.1132    7.45125   28.7265    …  -55.1076    -34.652
#   -0.010398   0.167404  0.240132   0.160561       0.122453   -0.00496477
#    0.441323  -0.202058  0.190315  -0.20021        0.135627    0.177957

# %%
plt.figure(dpi = 200)
hp.mollview(conv_binned_map[1,:], sub = (1,3,1), title = "convolved T")
hp.mollview(conv_binned_map[2,:], sub = (1,3,2), title = "convolved Q")
hp.mollview(conv_binned_map[3,:], sub = (1,3,3), title = "convolved U")
plt.figure(dpi = 200)
hp.mollview(in_map[1,:], sub = (1,3,1), title = "smoothed input T")
hp.mollview(in_map[2,:], sub = (1,3,2), title = "smoothed input Q")
hp.mollview(in_map[3,:], sub = (1,3,3), title = "smoothed input U")
# Out:
# Figure(PyObject <Figure size 1280x960 with 6 Axes>)
# Figure(PyObject <Figure size 1280x960 with 6 Axes>)
